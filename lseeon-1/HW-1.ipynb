# %%
'''
Исходный код к уроку 1.
Построение двухслойной нейронный сети для классификации цветков ириса
'''

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# sklearn здесь только, чтобы разделить выборку на тренировочную и тестовую
from sklearn.model_selection import train_test_split

# %%
### Шаг 2. Подготовка тренировочных данных
# получения данных из csv файла. укажите здесь путь к файлу Iris.csv
iris_data = pd.read_csv("./neural-networks-intro/Iris.csv")
# print(iris_data.head()) # расскоментируйте, чтобы посмотреть структуру данных

# репрезентация данных в виде графиков
g = sns.pairplot(iris_data.drop("Id", axis=1), hue="Species")
# plt.show() # расскоментируйте, чтобы посмотреть

# замена текстовых значений на цифровые
iris_data['Species'].replace(['Iris-setosa', 'Iris-virginica', 'Iris-versicolor'], [0, 1, 2], inplace=True)

# формирование входных данных
columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
x = pd.DataFrame(iris_data, columns=columns)
#x = normalize(x.as_matrix())
x = normalize(x.values)

# формирование выходных данных(результатов)
columns = ['Species']
y = pd.DataFrame(iris_data, columns=columns)
#y = y.as_matrix()
y = y.values
y = y.flatten()
y = to_one_hot(y)

# Разделение данных на тренировочные и тестовые
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
# вычисление сигмоид функции
def sigmoid(x):
     return 1 / (1 + np.exp(-x))

# вычисление производной от сигмоид функции
def sigm_deriv(x):
        return x * (1 - x)

# %%
# вычисление Relu функции
def ReLU(x):
         return x  *  (x  >  0)
# вычисление производной от Relu функции
def relu_deriv(x):
    return x>0

# %%
import time
### Шаг 3. Обученние нейронной сети
def fit_nn(neuron_numb=5, learning_rate=0.1, n_epochs=3000, act_fun=sigmoid, act_fun_deriv=sigm_deriv):
    time1 = time.time()

    # присваевание случайных весов
    w0 = 2*np.random.random((4, neuron_numb)) - 1 # для входного слоя   - 4 входа, 3 выхода
    w1 = 2*np.random.random((neuron_numb, 3)) - 1 # для внутреннего слоя - 5 входов, 3 выхода

    # массив для ошибок, чтобы потом построить график
    errors = []
    test_errors = []
    
    # процесс обучения
    for i in range(n_epochs):
    
        # прямое распространение(feed forward)
        layer0 = X_train
        layer1 = act_fun(np.dot(layer0, w0))
        layer2 = act_fun(np.dot(layer1, w1))
    
        # обратное распространение(back propagation) с использованием градиентного спуска
        layer2_error = y_train - layer2 # производная функции потерь = производная квадратичных потерь 
        layer2_delta = layer2_error * act_fun_deriv(layer2)
        
        layer1_error = layer2_delta.dot(w1.T)
        layer1_delta = layer1_error * act_fun_deriv(layer1)
        
        w1 += layer1.T.dot(layer2_delta) * learning_rate
        w0 += layer0.T.dot(layer1_delta) * learning_rate
        # метрика модели
        error = np.mean(np.abs(layer2_error))
        errors.append(error)
        accuracy = (1 - error) * 100

        test_layer0 = X_test
        test_layer1 = sigmoid(np.dot(test_layer0, w0))
        test_layer2 = sigmoid(np.dot(test_layer1, w1))

        test_layer2_error = y_test - test_layer2
        test_error = np.mean(np.abs(test_layer2_error))
        test_errors.append(test_error)
        test_accuracy = (1 - test_error) * 100

    time2 = time.time()
    
    return errors, accuracy, test_errors, test_accuracy, (time2-time1)*1000.0

errors, accuracy, test_errors, test_accuracy, ex_time = fit_nn()
print(ex_time)
# Out:
# 465.82579612731934

# %%
### Шаг 4. Демонстрация полученных результатов
# черчение диаграммы точности в зависимости от обучения
plt.figure(figsize = (16,5))
plt.plot(errors)
plt.xlabel('Обучение')
plt.ylabel('Ошибка')
plt.show() # расскоментируйте, чтобы посмотреть 

N = 50
plt.figure(figsize = (16,5))
plt.plot(layer2[:N,1], 'r',label = 'Y new')
plt.plot(y_train[:N,1],'g', label = 'Y train')
plt.xlabel('№ примера')
plt.ylabel('выход сети и целевой')
plt.legend( )
plt.show() # расскоментируйте, чтобы посмотреть 
        
print("Аккуратность нейронной сети " + str(round(accuracy,2)) + "%")
# Out:
# Аккуратность нейронной сети 97.14%

# %%
n_epochs = [100, 1000, 3000, 5000]
learning_rates = [0.01, 0.1, 1]
n_neurons = [2, 4, 6, 8, 10, 30]
act_funs = [{'name': 'sigmoid', 'fun': sigmoid, 'deriv': sigm_deriv}, {'name': 'ReLU', 'fun': ReLU, 'deriv': relu_deriv}]

# %%
results = []
for epochs in n_epochs:
    for learning_rate in learning_rates:
        for neuron_numb in n_neurons:
            for act_fun in act_funs:
                errors, accuracy, test_errors, test_accuracy, ex_time = fit_nn(neuron_numb=neuron_numb, learning_rate=learning_rate, n_epochs=epochs, act_fun=act_fun['fun'], act_fun_deriv=act_fun['deriv'])
                result = {'neuron_numb': neuron_numb, 'learning_rate': learning_rate, 'epochs': epochs, 'act_fun': act_fun['name'], 'ex_time': ex_time, 'accuracy': accuracy, 'test_accuracy': test_accuracy}
                results.append(result)
# Out:
# /home/alex/miniconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
results.sort(key=lambda val: val['test_accuracy'], reverse=True)

# %%
for res in results[:100]:
    print(res)
# Out:
# {'neuron_numb': 10, 'learning_rate': 1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 550.5940914154053, 'accuracy': 97.8842288962187, 'test_accuracy': 96.52134706123977}
# {'neuron_numb': 6, 'learning_rate': 1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 824.6588706970215, 'accuracy': 97.81719936875116, 'test_accuracy': 96.49793423477665}
# {'neuron_numb': 6, 'learning_rate': 1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 494.29917335510254, 'accuracy': 97.8714276501773, 'test_accuracy': 96.28626247288943}
# {'neuron_numb': 4, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 147.7956771850586, 'accuracy': 95.3149056645784, 'test_accuracy': 96.16840756261139}
# {'neuron_numb': 30, 'learning_rate': 0.1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 1481.4679622650146, 'accuracy': 97.43786219576393, 'test_accuracy': 96.15836298024394}
# {'neuron_numb': 8, 'learning_rate': 0.1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 863.3911609649658, 'accuracy': 97.42517633809085, 'test_accuracy': 96.15450944509469}
# {'neuron_numb': 10, 'learning_rate': 0.1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 920.7429885864258, 'accuracy': 97.39058130311918, 'test_accuracy': 96.13270221424057}
# {'neuron_numb': 4, 'learning_rate': 1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 443.65835189819336, 'accuracy': 97.23937915962233, 'test_accuracy': 96.12761532703587}
# {'neuron_numb': 8, 'learning_rate': 1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 515.4209136962891, 'accuracy': 97.42246649257726, 'test_accuracy': 95.96224887740786}
# {'neuron_numb': 10, 'learning_rate': 1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 930.6962490081787, 'accuracy': 97.82575686640962, 'test_accuracy': 95.85498063731285}
# {'neuron_numb': 8, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 171.48256301879883, 'accuracy': 98.02603128548148, 'test_accuracy': 95.7245494683211}
# {'neuron_numb': 4, 'learning_rate': 1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 762.1302604675293, 'accuracy': 97.95034521182583, 'test_accuracy': 95.63359342154028}
# {'neuron_numb': 4, 'learning_rate': 0.1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 744.065523147583, 'accuracy': 97.59587026837515, 'test_accuracy': 95.63200720419603}
# {'neuron_numb': 6, 'learning_rate': 0.1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 808.3813190460205, 'accuracy': 97.57336256063938, 'test_accuracy': 95.5941149488274}
# {'neuron_numb': 30, 'learning_rate': 0.1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 881.3157081604004, 'accuracy': 96.99851506252945, 'test_accuracy': 95.58143478851309}
# {'neuron_numb': 4, 'learning_rate': 0.1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 447.32022285461426, 'accuracy': 96.87017470800028, 'test_accuracy': 95.52554336959795}
# {'neuron_numb': 8, 'learning_rate': 0.1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 510.0970268249512, 'accuracy': 97.2407373192359, 'test_accuracy': 95.41833434470477}
# {'neuron_numb': 6, 'learning_rate': 0.1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 478.32298278808594, 'accuracy': 97.18548397675785, 'test_accuracy': 95.33618228126043}
# {'neuron_numb': 10, 'learning_rate': 0.1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 543.19167137146, 'accuracy': 97.15284335697734, 'test_accuracy': 95.32570163398186}
# {'neuron_numb': 10, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 182.0371150970459, 'accuracy': 97.22657167811728, 'test_accuracy': 94.7308053886572}
# {'neuron_numb': 10, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 183.04872512817383, 'accuracy': 95.24705636024711, 'test_accuracy': 93.7718282784634}
# {'neuron_numb': 30, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 294.0950393676758, 'accuracy': 95.18348227609735, 'test_accuracy': 93.72243687859356}
# {'neuron_numb': 6, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 160.6433391571045, 'accuracy': 95.14987943391186, 'test_accuracy': 93.71701639107798}
# {'neuron_numb': 8, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 169.3437099456787, 'accuracy': 95.12131085358607, 'test_accuracy': 93.59111966853561}
# {'neuron_numb': 4, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 147.89772033691406, 'accuracy': 94.9716579746204, 'test_accuracy': 93.46225778995719}
# {'neuron_numb': 6, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 160.13813018798828, 'accuracy': 95.78211789086514, 'test_accuracy': 92.34203365501541}
# {'neuron_numb': 30, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 1456.6426277160645, 'accuracy': 92.21247241659702, 'test_accuracy': 91.15119937029738}
# {'neuron_numb': 10, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 910.228967666626, 'accuracy': 91.58320373383589, 'test_accuracy': 90.55782458330384}
# {'neuron_numb': 6, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 809.2865943908691, 'accuracy': 91.42962346583741, 'test_accuracy': 90.21548445450954}
# {'neuron_numb': 8, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 863.1808757781982, 'accuracy': 90.27536937213411, 'test_accuracy': 89.30947621186158}
# {'neuron_numb': 4, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 735.6672286987305, 'accuracy': 87.76186196266801, 'test_accuracy': 86.93012465484911}
# {'neuron_numb': 8, 'learning_rate': 0.01, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 516.6785717010498, 'accuracy': 86.75681555446656, 'test_accuracy': 86.38581738286668}
# {'neuron_numb': 30, 'learning_rate': 0.01, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 883.2299709320068, 'accuracy': 86.03475507299427, 'test_accuracy': 85.8223804072032}
# {'neuron_numb': 10, 'learning_rate': 0.01, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 557.0864677429199, 'accuracy': 85.45382587210504, 'test_accuracy': 85.22187429312498}
# {'neuron_numb': 4, 'learning_rate': 0.01, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 440.13118743896484, 'accuracy': 85.12022622200728, 'test_accuracy': 84.86075756361545}
# {'neuron_numb': 2, 'learning_rate': 0.1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 698.4469890594482, 'accuracy': 85.31261618614334, 'test_accuracy': 84.19056386406882}
# {'neuron_numb': 2, 'learning_rate': 1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 693.2058334350586, 'accuracy': 84.8698496252404, 'test_accuracy': 84.09782618252882}
# {'neuron_numb': 2, 'learning_rate': 0.1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 411.85498237609863, 'accuracy': 84.45444588920489, 'test_accuracy': 83.45863253393726}
# {'neuron_numb': 2, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 135.5741024017334, 'accuracy': 84.90712362751242, 'test_accuracy': 83.0495687553865}
# {'neuron_numb': 6, 'learning_rate': 0.01, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 493.49260330200195, 'accuracy': 82.90462817144049, 'test_accuracy': 83.02338980919683}
# {'neuron_numb': 2, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 136.6889476776123, 'accuracy': 82.12274836029373, 'test_accuracy': 81.48448235669888}
# {'neuron_numb': 2, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 676.093578338623, 'accuracy': 80.29141950172946, 'test_accuracy': 80.23628189782045}
# {'neuron_numb': 2, 'learning_rate': 0.01, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 404.04438972473145, 'accuracy': 79.25053734006605, 'test_accuracy': 79.45200088824492}
# {'neuron_numb': 30, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 291.41926765441895, 'accuracy': 77.29873555954727, 'test_accuracy': 78.42503656273868}
# {'neuron_numb': 30, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 29.91199493408203, 'accuracy': 75.64908085728885, 'test_accuracy': 77.76995897745891}
# {'neuron_numb': 10, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 180.6776523590088, 'accuracy': 75.89093044098142, 'test_accuracy': 77.12937800407332}
# {'neuron_numb': 8, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 17.26245880126953, 'accuracy': 75.64753735455247, 'test_accuracy': 76.98857032955529}
# {'neuron_numb': 6, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 16.182661056518555, 'accuracy': 75.5116801639658, 'test_accuracy': 76.78454974343903}
# {'neuron_numb': 6, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 161.83853149414062, 'accuracy': 75.53762539017404, 'test_accuracy': 76.76774670701845}
# {'neuron_numb': 8, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 170.41659355163574, 'accuracy': 74.64467325806511, 'test_accuracy': 75.94031138807905}
# {'neuron_numb': 4, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 14.846563339233398, 'accuracy': 74.3185666988373, 'test_accuracy': 75.9253441993618}
# {'neuron_numb': 4, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 148.24223518371582, 'accuracy': 74.45527896168, 'test_accuracy': 75.81134585256639}
# {'neuron_numb': 2, 'learning_rate': 1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 410.79068183898926, 'accuracy': 82.8524289939436, 'test_accuracy': 75.71713613198918}
# {'neuron_numb': 10, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 18.440723419189453, 'accuracy': 75.26790833127231, 'test_accuracy': 75.497702864641}
# {'neuron_numb': 2, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 13.684272766113281, 'accuracy': 73.52888699011159, 'test_accuracy': 74.92483534062423}
# {'neuron_numb': 2, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 136.60740852355957, 'accuracy': 72.24782702028641, 'test_accuracy': 73.79348920144207}
# {'neuron_numb': 6, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 16.29781723022461, 'accuracy': 71.13069436680726, 'test_accuracy': 73.1198242839649}
# {'neuron_numb': 30, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 192.948579788208, 'accuracy': 66.66666666666667, 'test_accuracy': 66.66666666666667}
# {'neuron_numb': 30, 'learning_rate': 0.1, 'epochs': 3000, 'act_fun': 'ReLU', 'ex_time': 585.0443840026855, 'accuracy': 66.66666666666667, 'test_accuracy': 66.66666665932904}
# {'neuron_numb': 30, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'sigmoid', 'ex_time': 292.07324981689453, 'accuracy': 66.6666666590412, 'test_accuracy': 66.66666665919914}
# {'neuron_numb': 30, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 29.869794845581055, 'accuracy': 66.6666670545561, 'test_accuracy': 66.66666599876353}
# {'neuron_numb': 6, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 13.0615234375, 'accuracy': 66.66666666666667, 'test_accuracy': 66.66666282405693}
# {'neuron_numb': 8, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 17.502307891845703, 'accuracy': 66.66654161264643, 'test_accuracy': 66.66651941837483}
# {'neuron_numb': 8, 'learning_rate': 1, 'epochs': 5000, 'act_fun': 'sigmoid', 'ex_time': 885.8284950256348, 'accuracy': 66.66654420706543, 'test_accuracy': 66.66650588551464}
# {'neuron_numb': 30, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 193.65906715393066, 'accuracy': 66.66666666666667, 'test_accuracy': 66.6662092880983}
# {'neuron_numb': 30, 'learning_rate': 1, 'epochs': 3000, 'act_fun': 'ReLU', 'ex_time': 607.1639060974121, 'accuracy': 66.66666666666667, 'test_accuracy': 66.66602468387865}
# {'neuron_numb': 4, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 15.033960342407227, 'accuracy': 66.66375592250631, 'test_accuracy': 66.66195800964631}
# {'neuron_numb': 30, 'learning_rate': 0.1, 'epochs': 5000, 'act_fun': 'ReLU', 'ex_time': 956.4769268035889, 'accuracy': 66.66666666666667, 'test_accuracy': 66.60053476545448}
# {'neuron_numb': 10, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 149.97386932373047, 'accuracy': 66.66666666666667, 'test_accuracy': 66.46272791107786}
# {'neuron_numb': 30, 'learning_rate': 0.01, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 19.170284271240234, 'accuracy': 66.66666666666667, 'test_accuracy': 66.21860598662626}
# {'neuron_numb': 30, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 190.9332275390625, 'accuracy': 66.66666666666667, 'test_accuracy': 64.27760756617627}
# {'neuron_numb': 10, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 137.79258728027344, 'accuracy': 66.66666666666667, 'test_accuracy': 63.9811290636642}
# {'neuron_numb': 8, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'ReLU', 'ex_time': 672.7538108825684, 'accuracy': 86.02585335277756, 'test_accuracy': 63.72374768383588}
# {'neuron_numb': 10, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 14.664411544799805, 'accuracy': 66.66666666666667, 'test_accuracy': 63.51848891137709}
# {'neuron_numb': 8, 'learning_rate': 0.1, 'epochs': 3000, 'act_fun': 'ReLU', 'ex_time': 394.00339126586914, 'accuracy': 66.66666666666667, 'test_accuracy': 62.91368020716999}
# {'neuron_numb': 30, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 20.130634307861328, 'accuracy': 66.66666666666667, 'test_accuracy': 62.89978307768111}
# {'neuron_numb': 10, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 13.926982879638672, 'accuracy': 66.66666666666667, 'test_accuracy': 62.057339417735705}
# {'neuron_numb': 10, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 18.74995231628418, 'accuracy': 70.93151738722811, 'test_accuracy': 60.99289168221128}
# {'neuron_numb': 2, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 13.903141021728516, 'accuracy': 55.24349548888762, 'test_accuracy': 60.259323717450556}
# {'neuron_numb': 30, 'learning_rate': 0.01, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 29.65521812438965, 'accuracy': 59.957812402939204, 'test_accuracy': 60.18285486914079}
# {'neuron_numb': 6, 'learning_rate': 0.1, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 126.93309783935547, 'accuracy': 66.66666666666667, 'test_accuracy': 59.729806514638426}
# {'neuron_numb': 4, 'learning_rate': 0.01, 'epochs': 3000, 'act_fun': 'ReLU', 'ex_time': 384.75918769836426, 'accuracy': 84.7547348473129, 'test_accuracy': 58.91010431126066}
# {'neuron_numb': 30, 'learning_rate': 1, 'epochs': 5000, 'act_fun': 'ReLU', 'ex_time': 968.991756439209, 'accuracy': 66.66666666666667, 'test_accuracy': 58.75446154149348}
# {'neuron_numb': 8, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 13.342142105102539, 'accuracy': 66.66666666666667, 'test_accuracy': 58.68421317740102}
# {'neuron_numb': 6, 'learning_rate': 1, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 127.54201889038086, 'accuracy': 66.66666666666667, 'test_accuracy': 58.67949131187089}
# {'neuron_numb': 8, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 132.857084274292, 'accuracy': 91.93110422364765, 'test_accuracy': 58.102272291543855}
# {'neuron_numb': 10, 'learning_rate': 1, 'epochs': 5000, 'act_fun': 'ReLU', 'ex_time': 747.178316116333, 'accuracy': 66.66666666666667, 'test_accuracy': 58.02996569255407}
# {'neuron_numb': 8, 'learning_rate': 1, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 13.524293899536133, 'accuracy': 66.66666666666667, 'test_accuracy': 57.74082220671113}
# {'neuron_numb': 6, 'learning_rate': 0.1, 'epochs': 5000, 'act_fun': 'ReLU', 'ex_time': 645.1051235198975, 'accuracy': 66.66666666666667, 'test_accuracy': 57.44031724212091}
# {'neuron_numb': 6, 'learning_rate': 0.01, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 16.204118728637695, 'accuracy': 57.20113725794332, 'test_accuracy': 56.89667308149755}
# {'neuron_numb': 8, 'learning_rate': 0.01, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 17.287254333496094, 'accuracy': 56.97036526983585, 'test_accuracy': 56.71669373380757}
# {'neuron_numb': 4, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'ReLU', 'ex_time': 606.7872047424316, 'accuracy': 66.66666666666667, 'test_accuracy': 56.631150767587314}
# {'neuron_numb': 30, 'learning_rate': 0.01, 'epochs': 3000, 'act_fun': 'ReLU', 'ex_time': 571.9790458679199, 'accuracy': 66.66666666666667, 'test_accuracy': 56.479200658663}
# {'neuron_numb': 4, 'learning_rate': 0.01, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 14.911890029907227, 'accuracy': 56.718308557571696, 'test_accuracy': 56.32403751979063}
# {'neuron_numb': 30, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 20.343780517578125, 'accuracy': 66.66666666666667, 'test_accuracy': 55.86249921510487}
# {'neuron_numb': 6, 'learning_rate': 0.1, 'epochs': 100, 'act_fun': 'ReLU', 'ex_time': 12.906551361083984, 'accuracy': 66.66666666666667, 'test_accuracy': 55.82124911505192}
# {'neuron_numb': 30, 'learning_rate': 0.01, 'epochs': 5000, 'act_fun': 'ReLU', 'ex_time': 981.191873550415, 'accuracy': 66.66666666666667, 'test_accuracy': 55.818079768590756}
# {'neuron_numb': 4, 'learning_rate': 0.01, 'epochs': 1000, 'act_fun': 'ReLU', 'ex_time': 123.44050407409668, 'accuracy': 81.97545518007117, 'test_accuracy': 55.64647971225965}
# {'neuron_numb': 2, 'learning_rate': 0.01, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 14.872312545776367, 'accuracy': 55.962403443694356, 'test_accuracy': 55.50952659975532}
# {'neuron_numb': 10, 'learning_rate': 0.01, 'epochs': 100, 'act_fun': 'sigmoid', 'ex_time': 18.40806007385254, 'accuracy': 55.86170189831399, 'test_accuracy': 55.415408212267195}

# %% [markdown]
# Лучший результата показала следующая комбинация параметров:
# {'neuron_numb': 10, 'learning_rate': 1, 'epochs': 3000, 'act_fun': 'sigmoid', 'ex_time': 550.5940914154053, 'accuracy': 97.8842288962187, 'test_accuracy': 96.52134706123977}
#
# По приведенному списку видно, что само по себе увеличение или уменьшенее какого-то параметра не дает безусловного выигрыша по точности (разве только увеличение learning_rate, но вданном случае, я думаю, это специфика задачи, в целом с ним нужно быть осторожнее). Например простое увеличение числа нейронов не всегда оптимально.
#
# В целом, я думаю, можно сказать, что функция активация в виде сигмоида для данной задачи лучше, чем ReLU, а увеличение числа итераций положительно сказывается на точности (что ожидаемо)
